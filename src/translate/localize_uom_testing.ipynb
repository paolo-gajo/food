# %%
import re
import json

en_mapping = {
        '½': '1/2', '¼': '1/4', '¾': '3/4',
        '⅓': '1/3', '⅔': '2/3', '⅕': '1/5',
        '⅖': '2/5', '⅗': '3/5', '⅘': '4/5',
        '⅙': '1/6', '⅚': '5/6', '⅛': '1/8',
        '⅜': '3/8', '⅝': '5/8', '⅞': '7/8',
    }
    
it_mapping = {
    'a lisca di pesce': 'lb',
    'può': 'barattolo',
    'butter': 'burro',
    'onion': 'cipolla',
    'calce': 'lime',
    'farina di tutti i tipi': 'farina 00',
    'tutti gli usi': '00',
    'terra': 'macinato',
    'prosciugato': 'scolato',
    'hashish': 'hash browns',
    'bastoni': 'bastoncini',
    'bollito duro': 'sodo',
    'spuntato': 'scoppiato',
    'gherigli': 'chicchi',
    'sogno': 'panna',
    'trattino': 'pizzico',
    'trattini': 'pizzichi',
    'strapazzato': 'strapazzate',
    'Irlandese': 'irlandese',
    'miniature': 'mini',
    'condimento ranch': 'salsa ranch',
    'avena arrotolata': "fiocchi d'avena",
    'periodo di harina': 'farina di mais',
    'condimento mille isole': 'salsa Thousand Island',
    'seni': 'petti',
    'vaso': 'barattolo',
    'salice piccante': 'salsa piccante',
    'scuoiato': 'senza la pelle',
    "Un'oncia": "1 oncia",
    'peperoni jalapeno': 'peperoncini jalapeno',
    'mite': 'delicato',
    'drenato': 'scolato',
    'condimento per insalata mille isole': 'salsa Thousand Island per insalata',
    'pepperoncini peppers': 'peperoncini',
    'mirino': 'mirin',
    'feta cheese': 'formaggio feta',
    'massa': 'impasto',
    'spaccatura': 'con taglio',
    'dimezzato': 'tagliato in due',
    'impreparato': 'senza lievito',
    'maneggevole': 'manciata',
    'saldamente imballato': 'compatto',
    'gms': 'g',
    'magro macinato': 'macinato magro',
    'piccolo farinoso': 'piccole e farinose',
    'condimento greco universale': 'condimento greco',
    'offerte di pollo': 'filetti di pollo',
    'pelle accesa o spenta': 'con o senza pelle',
    'spruzzi': 'sprinkles',
    'spilli': 'pizzichi',
    'farina da forno': 'farina 00',
    'per cuocere il riso in': 'per cuocere il riso',
    'dragare': 'per infarinare',
    'Alfredo Salice': 'salsa Alfredo',
    'dice into 1/4" squares': 'taglia a cubetti di 0.5 cm',
    'base di pollo': 'brodo di pollo',
    'alveolare': 'senza torsolo',
    'squartato': 'tagliato in quattro',
    'vanilla essence': 'estratto di vaniglia',
    'Riso minuto': 'Minute Rice',
    



    
}

mappings = {
    'en': en_mapping,
    'it': it_mapping,
}

def sub_shift(json_data, mappings, *, lang):
    text_key = f'text_{lang}'
    ents_key = f'ents_{lang}'

    pattern = re.compile('|'.join(re.escape(key) for key in mappings[lang].keys()))

    for j, annotation in enumerate(json_data['annotations']):
        text = annotation[text_key]
        entities = annotation[ents_key]
        adjustment = 0

        for match in re.finditer(pattern, text):
            match_index = match.start() + adjustment
            match_contents = match.group()
            subbed_text = mappings[lang][match_contents]

            len_diff = len(subbed_text) - len(match_contents)
            text = text[:match_index] + subbed_text + text[match_index + len(match_contents):]
            # Adjust the indices of subsequent annotations
            for entity in entities:
                start, end = entity[0], entity[1]
                if start <= match_index and end > match_index:
                    entity[0] = start
                    entity[1] = end + len_diff
                if start > match_index:
                    entity[0] = start + len_diff
                    entity[1] = end + len_diff
            adjustment += len_diff
        annotation[text_key] = text.replace("⁄", "/")
        # print(j, [annotation[text_key][entities[i][0]:entities[i][1]] for i in range(len(entities))])
    return json_data

class Converter:
    def __init__(self, *, patterns) -> None:
        self.uom = None

    def str_frac_to_float(self, s):
        nums = [float(n) for n in s.split('/')]
        if len(nums)>1:
            out = (nums[0]*self.uom)/nums[1]
            if out>10:
                return int(out)
            else:
                return round(out, ndigits=1)
        out = nums[0]*self.uom
        if out>10:
            return int(out)
        else:
            return round(out, ndigits=1)

    @staticmethod
    def tighten_slash(s):
        slash_pattern = r'\s*/\s*'
        return re.sub(slash_pattern, '/', s.strip())

    def convert_num(self, input_string):
        extremes = [s for s in input_string.split('-') if s != '']
        nums = []
        for ext in extremes:
            num_buffer = 0
            int_and_frac = self.tighten_slash(ext).split()
            num_buffer = sum(self.str_frac_to_float(part) for part in int_and_frac)
            nums.append(num_buffer)
        return ' - '.join([str(n) for n in nums])
    
    def localize_ingredients(self, sample, lang = 'it'):
        text_key = f'text_{lang}'
        ents_key = f'ents_{lang}'
        text = sample[text_key]
        ents = sample[ents_key]
        print(sample['text_en'])
        print([sample['text_en'][sample['ents_en'][i][0]:sample['ents_en'][i][1]] for i in range(len(sample['ents_en']))])
        print(text)
        # print([text[ents[i][0]:ents[i][1]] for i in range(len(ents))])
        
        for pattern in pattern_list:
            adjustment = 0
            
            regex = re.compile(pattern['pattern']) 
            matches = re.finditer(regex, text)
            tuple_matches = re.findall(regex, text)
            for i, match in enumerate(matches):
                match_text = tuple_matches[i]
                l_strip_diff = len(match.group()) - len(match.group().lstrip())
                match_index = match.start() + adjustment + l_strip_diff
                if pattern['type'] == 'quantity':
                    converter.uom = pattern['ratio']
                    converted_text = self.convert_num(match_text.replace(',', '.')).replace('.', ',').replace(',0', '') + ' '
                elif pattern['type'] == 'uom':
                    converted_text = pattern['uom']
                elif pattern['type'] == 'plain':
                    converted_text = pattern['sub']

                len_diff = len(converted_text) - len(match_text)
                text = text[:match_index] + converted_text + text[match_index - l_strip_diff + len(match_text):]
                # Adjust the indices of subsequent annotations
                for ent in ents:
                    start, end = ent[0], ent[1]
                    if end > match_index:
                        ent[1] = end + len_diff
                    if start > match_index:
                        ent[0] = start + len_diff
                        ent[1] = end + len_diff
                adjustment += len_diff
        sample[text_key] = text
        print(text)
        print([text[ents[i][0]:ents[i][1]] for i in range(len(ents))])
        print('---------------')

pattern_list = [
    # fix uom
    {'pattern': r'chili pepper(?!\w)', 'type': 'plain', 'sub': 'peperoncino'},
    {'pattern': r'cancellato(?!\w)', 'type': 'plain', 'sub': 'lavate'},
    {'pattern': r'(?<=cucchiai\s)come(?!\w)', 'type': 'plain', 'sub': 'menta'},
    {'pattern': r'come(?=\s(?:foglie|foglia))', 'type': 'plain', 'sub': 'menta'},

    {'pattern': r'(\d[-/\.\,\d\s]*)tazz.(?!\w)', 'ratio': 236, 'uom': 'g', 'type': 'quantity'},
    {'pattern': r'(\d[-/\.\,\d\s]*)(?:(?:once fluide)|(?:oncia fluida)|once|oncia|oz\.|oz)(?!\w)', 'ratio': 28.35, 'uom': 'g', 'type': 'quantity'},
    {'pattern': r'(\d[-/\.\,\d\s]*)(?:chili|chilo|lbs?\.?|libbre|pounds|pound)(?!\w)', 'ratio': 0.45, 'uom': 'kg', 'type': 'quantity'},
    {'pattern': r'(\d[-/\.\,\d\s]*)(?:di pollice|pollic.)(?!\w)', 'ratio': 2.54, 'uom': 'cm', 'type': 'quantity'},
    {'pattern': r'(\d[-/\.\,\d\s]*)(?:pinte|pinta)(?!\w)', 'ratio': 473, 'uom': 'ml', 'type': 'quantity'},

    {'pattern': r'tazz.(?!\w)', 'ratio': 236, 'uom': 'g', 'type': 'uom'},
    {'pattern': r'(?:(?:once fluide)|(?:oncia fluida)|once|oncia|oz\.|oz)(?!\w)', 'ratio': 28.35, 'uom': 'g', 'type': 'uom'},
    {'pattern': r'(?:chili|chilo|lbs?\.?|libbre|pounds|pound)(?!\w)', 'ratio': 0.45, 'uom': 'kg', 'type': 'uom'},
    {'pattern': r'(?:di pollice|pollic.)(?!\w)', 'ratio': 2.54, 'uom': 'cm', 'type': 'uom'},
    {'pattern': r'(?:pinte|pinta)(?!\w)', 'ratio': 473, 'uom': 'ml', 'type': 'uom'},

    {'pattern': r'tigli(?!\w)', 'type': 'plain', 'sub': 'lime'},
    {'pattern': r'orso(?!\w)', 'type': 'plain', 'sub': 'birra'},
    {'pattern': r'orecchie(?!\w)', 'type': 'plain', 'sub': 'pannocchie'}
]

converter = Converter(patterns=pattern_list)

json_file = '../../data/EW-TASTE_en-it_DEEPL.json'
with open(json_file, 'r', encoding='utf-8') as file:
    data = json.load(file)

# clean up translation mistakes by doing simple substitutions first with this function
modified_data = sub_shift(data, mappings, lang = 'it')

# do quantity and unit of measure conversions
for i, line in enumerate(modified_data['annotations']):
    print(i)
    converter.localize_ingredients(line)
# converter.localize_ingredients(modified_data['annotations'][139])
# save to updated json file with different name
with open(json_file[:-5] + '_localized_uom.json', 'w', encoding='utf-8') as file:
    json.dump(data, file, ensure_ascii=False, indent=4)
# Out:
# 0
# 5 ounces rum;4 ounces triple sec;3 ounces Tia Maria;20 ounces orange juice
# ['5', 'ounces', 'rum', '4', 'ounces', 'triple sec', '3', 'ounces', 'Tia Maria', '20', 'ounces', 'orange juice']
# 5 once rum;4 once triplo sec;3 once Zia Maria;20 once succo d'arancia
# 141 g rum;113 g triplo sec;85 g Zia Maria;567 g succo d'arancia
# ['141', 'g', 'rum', '113', 'g', 'triplo sec', '85', 'g', 'Zia Maria', '567', 'g', "succo d'arancia"]
# ---------------
# 1
# 2 tubes cinnamon roll, refrigerated, with icing;4 tablespoons butter, melted;6 eggs;1/2 cup milk;2 teaspoons cinnamon;2 teaspoons vanilla;1 cup maple syrup
# ['2', 'tubes', 'cinnamon roll', 'refrigerated', 'with', 'icing', '4', 'tablespoons', 'butter', 'melted', '6', 'eggs', '1/2', 'cup', 'milk', '2', 'teaspoons', 'cinnamon', '2', 'teaspoons', 'vanilla', '1', 'cup', 'maple syrup']
# 2 tubi rotolo alla cannella, refrigerato, con glassa;4 cucchiai burro, fuso;6 uova;1/2 tazza latte;2 cucchiaini cannella;2 cucchiaini vaniglia;1 tazza sciroppo d'acero
# 2 tubi rotolo alla cannella, refrigerato, con glassa;4 cucchiai burro, fuso;6 uova;118 g latte;2 cucchiaini cannella;2 cucchiaini vaniglia;236 g sciroppo d'acero
# ['2', 'tubi', 'rotolo alla cannella', 'refrigerato', 'con', 'glassa', '4', 'cucchiai', 'burro', 'fuso', '6', 'uova', '118', 'g', 'latte', '2', 'cucchiaini', 'cannella', '2', 'cucchiaini', 'vaniglia', '236', 'g', "sciroppo d'acero"]
# ---------------
# 2
# 4 ripe coconuts;1 cup evaporated milk;1 cup gin;3 tablespoons sugar (optional);1 teaspoon ground cinnamon;1/2 teaspoon freshly grated nutmeg
# ['4', 'ripe', 'coconuts', '1', 'cup', 'evaporated milk', '1', 'cup', 'gin', '3', 'tablespoons', 'sugar', '1', 'teaspoon', 'ground', 'cinnamon', '1/2', 'teaspoon', 'freshly grated', 'nutmeg']
# 4 maturo noci di cocco;1 tazza latte evaporato;1 tazza gin;3 cucchiai zucchero (1 cucchiaino macinato cannella;1/2 cucchiaino grattugiato fresco noce moscata
# 4 maturo noci di cocco;236 g latte evaporato;236 g gin;3 cucchiai zucchero (1 cucchiaino macinato cannella;1/2 cucchiaino grattugiato fresco noce moscata
# ['4', 'maturo', 'noci di cocco', '236', 'g', 'latte evaporato', '236', 'g', 'gin', '3', 'cucchiai', 'zucchero', '1', 'cucchiaino', 'macinato', 'cannella', '1/2', 'cucchiaino', 'grattugiato fresco', 'noce moscata']
# ---------------
# 3
# 1 sheet graham cracker (broken in half);2 pieces milk chocolate candy bars;1 marshmallows;6 -8 fresh blueberries;2 thick strawberry slices
# ['1', 'sheet', 'graham cracker', 'broken in half', '2', 'pieces', 'milk chocolate candy bars', '1', 'marshmallows', '6 -8', 'fresh', 'blueberries', '2', 'thick', 'strawberry slices']
# 1 foglio cracker graham (spezzato a metà);2 pezzi barrette di cioccolato al latte;1 marshmallow;6 -8 fresco mirtilli;2 spessa fette di fragola
# 1 foglio cracker graham (spezzato a metà);2 pezzi barrette di cioccolato al latte;1 marshmallow;6 -8 fresco mirtilli;2 spessa fette di fragola
# ['1', 'foglio', 'cracker graham', 'spezzato a metà', '2', 'pezzi', 'barrette di cioccolato al latte', '1', 'marshmallow', '6 -8', 'fresco', 'mirtilli', '2', 'spessa', 'fette di fragola']
# ---------------
# 4
# 1 (8 ounce) package crescent rolls;8 slices deli ham;4 teaspoons prepared mustard;1 cup shredded swiss cheese or 1 cup cheddar cheese;2 tablespoons sesame seeds (optional)
# ['1', '8', 'ounce', 'package', 'crescent rolls', '8', 'slices', 'deli ham', '4', 'teaspoons', 'prepared', 'mustard', '1', 'cup', 'shredded', 'swiss cheese', '1', 'cup', 'cheddar cheese', '2', 'tablespoons', 'sesame seeds']
# 1 (8 oncia) pacchetto involtini primavera;8 fette prosciutto crudo;4 cucchiaini preparato senape;1 tazza triturati formaggio svizzero 1 tazza formaggio cheddar;2 cucchiai semi di sesamo (
# 1 (226 g) pacchetto involtini primavera;8 fette prosciutto crudo;4 cucchiaini preparato senape;236 g triturati formaggio svizzero 236 g formaggio cheddar;2 cucchiai semi di sesamo (
# ['1', '226', 'g', 'pacchetto', 'involtini primavera', '8', 'fette', 'prosciutto crudo', '4', 'cucchiaini', 'preparato', 'senape', '236', 'g', 'triturati', 'formaggio svizzero', '236', 'g', 'formaggio cheddar', '2', 'cucchiai', 'semi di sesamo']
# ---------------
# 5
# 10 bone in chicken thighs (2-3/4 lb., skins removed);16 ounces TACO BELL® Thick & Chunky Salsa;1 onion (chopped Save-A-Lot - $0.99 thru 01/23);2 tablespoons curry powder;1 cup Knudsen Light Sour Cream (or BREAKSTONE'S Reduced Fat)
# ['10', 'bone in', 'chicken', 'thighs', '2-3/4', 'lb.', 'skins removed', '16', 'ounces', 'TACO BELL® Thick & Chunky Salsa', '1', 'onion', 'chopped', '2', 'tablespoons', 'curry powder', '1', 'cup', 'Sour Cream', 'Reduced Fat']
# 10 bone in pollo cosce (2-3/4 lb., pelli rimosse);16 once Salsa TACO BELL® spessa e piccante;1 cipolla (tritato 2 cucchiai curry in polvere;1 tazza Panna acida (Grasso ridotto)
# 10 bone in pollo cosce (0,9 - 0,3 kg, pelli rimosse);453 g Salsa TACO BELL® spessa e piccante;1 cipolla (tritato 2 cucchiai curry in polvere;236 g Panna acida (Grasso ridotto)
# ['10', 'bone in', 'pollo', 'cosce', '0,9 - 0,3', 'kg', 'pelli rimosse', '453', 'g', 'Salsa TACO BELL® spessa e piccante', '1', 'cipolla', 'tritato', '2', 'cucchiai', 'curry in polvere', '236', 'g', 'Panna acida', 'Grasso ridotto']
# ---------------
# 6
# 2 medium baking potatoes (6 - 8 oz. each);2 tablespoons of melted butter;1/4 teaspoon garlic salt or 1/4 teaspoon seasoning salt;1/8 teaspoon pepper;sour cream, as topping (optional);chives, as topping (optional)
# ['2', 'medium', 'baking potatoes', '6 - 8', 'oz.', '2', 'tablespoons', 'melted', 'butter', '1/4', 'teaspoon', 'garlic salt', '1/4', 'teaspoon', 'seasoning salt', '1/8', 'teaspoon', 'pepper', 'sour cream', 'as topping', 'chives', 'as topping']
# 2 medio patate al forno (6 - 8 oz. 2 cucchiai fuso burro;1/4 cucchiaino sale all'aglio 1/4 cucchiaino sale da cucina;1/8 cucchiaino pepe;panna acida, come guarnizione (erba cipollina, come guarnizione (
# 2 medio patate al forno (170 - 226 g 2 cucchiai fuso burro;1/4 cucchiaino sale all'aglio 1/4 cucchiaino sale da cucina;1/8 cucchiaino pepe;panna acida, come guarnizione (erba cipollina, come guarnizione (
# ['2', 'medio', 'patate al forno', '170 - 226', 'g', '2', 'cucchiai', 'fuso', 'burro', '1/4', 'cucchiaino', "sale all'aglio", '1/4', 'cucchiaino', 'sale da cucina', '1/8', 'cucchiaino', 'pepe', 'panna acida', 'come guarnizione', 'erba cipollina', 'come guarnizione']
# ---------------
# 7
# carrots;canning salt (optional);carrots (Sweet);brown sugar;2 cups brown sugar;2 cups water;1 cup orange juice
# ['carrots', 'canning salt', 'carrots', 'Sweet', 'brown', 'sugar', '2', 'cups', 'brown', 'sugar', '2', 'cups', 'water', '1', 'cup', 'orange juice']
# carote;sale da cucina (carote (Dolce);marrone zucchero;2 tazze marrone zucchero;2 tazze acqua;1 tazza succo d'arancia
# carote;sale da cucina (carote (Dolce);marrone zucchero;472 g marrone zucchero;472 g acqua;236 g succo d'arancia
# ['carote', 'sale da cucina', 'carote', 'Dolce', 'marrone', 'zucchero', '472', 'g', 'marrone', 'zucchero', '472', 'g', 'acqua', '236', 'g', "succo d'arancia"]
# ---------------
# 8
# 1 cup chocolate chips;1 cup heavy cream;1 egg;whipped cream;1 teaspoon vanilla extract
# ['1', 'cup', 'chocolate chips', '1', 'cup', 'heavy cream', '1', 'egg', 'whipped', 'cream', '1', 'teaspoon', 'vanilla extract']
# 1 tazza gocce di cioccolato;1 tazza panna pesante;1 uovo;montata crema;1 cucchiaino estratto di vaniglia
# 236 g gocce di cioccolato;236 g panna pesante;1 uovo;montata crema;1 cucchiaino estratto di vaniglia
# ['236', 'g', 'gocce di cioccolato', '236', 'g', 'panna pesante', '1', 'uovo', 'montata', 'crema', '1', 'cucchiaino', 'estratto di vaniglia']
# ---------------
# 9
# 1 lime, cut in wedges (optional);kosher salt (optional);1 cup ruby red grapefruit juice;1/2 cup freshly squeezed lime juice (4 limes);1 cup orange liqueur, such a Triple Sec;2 cups ice;1 cup white tequila
# ['1', 'lime', 'cut in wedges', 'kosher salt', '1', 'cup', 'ruby red', 'grapefruit juice', '1/2', 'cup', 'freshly squeezed', 'lime juice', '4', 'limes', '1', 'cup', 'orange liqueur', '2', 'cups', 'ice', '1', 'cup', 'white', 'tequila']
# 1 lime, tagliato a spicchi (sale kosher (1 tazza rosso rubino succo di pompelmo;1/2 tazza spremuta fresca succo di lime (4 tigli);1 tazza liquore all'arancia, 2 tazze ghiaccio;1 tazza bianco tequila
# 1 lime, tagliato a spicchi (sale kosher (236 g rosso rubino succo di pompelmo;118 g spremuta fresca succo di lime (4 lime);236 g liquore all'arancia, 472 g ghiaccio;236 g bianco tequila
# ['1', 'lime', 'tagliato a spicchi', 'sale kosher', '236', 'g', 'rosso rubino', 'succo di pompelmo', '118', 'g', 'spremuta fresca', 'succo di lime', '4', 'lime', '236', 'g', "liquore all'arancia", '472', 'g', 'ghiaccio', '236', 'g', 'bianco', 'tequila']
# ---------------
# 10
# 3 avocados (ripe, I live in California now so I use Hass, I actually prefer them to the larger, fruitier avocados in South Florida);1 1/2 cups fresh tomatoes (cut into bite-sized chunks);1 red onion (sliced);3 tablespoons white vinegar;2 tablespoons extra-virgin olive oil;salt;pepper
# ['3', 'avocados', 'ripe', '1 1/2', 'cups', 'fresh', 'tomatoes', 'cut into bite-sized chunks', '1', 'red', 'onion', 'sliced', '3', 'tablespoons', 'white', 'vinegar', '2', 'tablespoons', 'extra-virgin', 'olive oil', 'salt', 'pepper']
# 3 avocado (maturo, 1 1/2 tazze fresco pomodori (tagliato a pezzetti);1 rosso cipolla (affettato);3 cucchiai bianco aceto;2 cucchiai extravergine olio d'oliva;sale;pepe
# 3 avocado (maturo, 354 g fresco pomodori (tagliato a pezzetti);1 rosso cipolla (affettato);3 cucchiai bianco aceto;2 cucchiai extravergine olio d'oliva;sale;pepe
# ['3', 'avocado', 'maturo', '354', 'g', 'fresco', 'pomodori', 'tagliato a pezzetti', '1', 'rosso', 'cipolla', 'affettato', '3', 'cucchiai', 'bianco', 'aceto', '2', 'cucchiai', 'extravergine', "olio d'oliva", 'sale', 'pepe']
# ---------------
# 11
# 1 ounce Kahlua;1/2 ounce tequila;6 ounces hot coffee;whipped cream
# ['1', 'ounce', 'Kahlua', '1/2', 'ounce', 'tequila', '6', 'ounces', 'hot', 'coffee', 'whipped', 'cream']
# 1 oncia Kahlua;1/2 oncia tequila;6 once caldo caffè;montata crema
# 28 g Kahlua;14 g tequila;170 g caldo caffè;montata crema
# ['28', 'g', 'Kahlua', '14', 'g', 'tequila', '170', 'g', 'caldo', 'caffè', 'montata', 'crema']
# ---------------
# 12
# 5 eggs;150 grams sugar (/, 5 1/3 ounces);100 grams all purpose flour (/, 3 1/2 ounces);1 teaspoon baking powder
# ['5', 'eggs', '150', 'grams', 'sugar', '5 1/3', 'ounces', '100', 'grams', 'all purpose flour', '3 1/2', 'ounces', '1', 'teaspoon', 'baking powder']
# 5 uova;150 grammi zucchero (/, 5 1/3 once);100 grammi farina 00 (/, 3 1/2 once);1 cucchiaino lievito in polvere
# 5 uova;150 grammi zucchero (/, 150,5 g);100 grammi farina 00 (/, 99 g);1 cucchiaino lievito in polvere
# ['5', 'uova', '150', 'grammi', 'zucchero', '150,5', 'g', '100', 'grammi', 'farina 00', '99', 'g', '1', 'cucchiaino', 'lievito in polvere']
# ---------------
# 13
# 15 oz garbanzo beans, 1 can, drained and rinsed;1/2 teaspoon salt;1/2 teaspoon ground cumin;1 clove garlic, minced;16 oz roasted red pepper, 1 jar, drained;1 tablespoon lemon juice;1 tablespoon extra virgin olive oil
# ['15', 'oz', 'garbanzo beans', '1', 'can', 'drained', 'rinsed', '1/2', 'teaspoon', 'salt', '1/2', 'teaspoon', 'ground', 'cumin', '1', 'clove', 'garlic', 'minced', '16', 'oz', 'roasted', 'red', 'pepper', '1', 'jar', 'drained', '1', 'tablespoon', 'lemon juice', '1', 'tablespoon', 'extra virgin', 'olive oil']
# 15 oz ceci, 1 barattolo, scolato risciacquato;1/2 cucchiaino sale;1/2 cucchiaino macinato cumino;1 chiodo di garofano aglio, tritato;16 oz arrostito rosso pepe, 1 barattolo, scolato;1 cucchiaio succo di limone;1 cucchiaio extra vergine olio d'oliva
# 425 g ceci, 1 barattolo, scolato risciacquato;1/2 cucchiaino sale;1/2 cucchiaino macinato cumino;1 chiodo di garofano aglio, tritato;453 g arrostito rosso pepe, 1 barattolo, scolato;1 cucchiaio succo di limone;1 cucchiaio extra vergine olio d'oliva
# ['425', 'g', 'ceci', '1', 'barattolo', 'scolato', 'risciacquato', '1/2', 'cucchiaino', 'sale', '1/2', 'cucchiaino', 'macinato', 'cumino', '1', 'chiodo di garofano', 'aglio', 'tritato', '453', 'g', 'arrostito', 'rosso', 'pepe', '1', 'barattolo', 'scolato', '1', 'cucchiaio', 'succo di limone', '1', 'cucchiaio', 'extra vergine', "olio d'oliva"]
# ---------------
# 14
# 15 oz garbanzo beans, 1 can, drained and rinsed;1/4 teaspoon salt;1 clove garlic;1/2 teaspoon ground cumin;1/2 cup basil pesto;1 tablespoon lemon juice;2 tablespoons water
# ['15', 'oz', 'garbanzo beans', '1', 'can', 'drained', 'rinsed', '1/4', 'teaspoon', 'salt', '1', 'clove', 'garlic', '1/2', 'teaspoon', 'ground', 'cumin', '1/2', 'cup', 'basil pesto', '1', 'tablespoon', 'lemon juice', '2', 'tablespoons', 'water']
# 15 oz ceci, 1 barattolo, scolato risciacquato;1/4 cucchiaino sale;1 chiodo di garofano aglio;1/2 cucchiaino macinato cumino;1/2 tazza pesto di basilico;1 cucchiaio succo di limone;2 cucchiai acqua
# 425 g ceci, 1 barattolo, scolato risciacquato;1/4 cucchiaino sale;1 chiodo di garofano aglio;1/2 cucchiaino macinato cumino;118 g pesto di basilico;1 cucchiaio succo di limone;2 cucchiai acqua
# ['425', 'g', 'ceci', '1', 'barattolo', 'scolato', 'risciacquato', '1/4', 'cucchiaino', 'sale', '1', 'chiodo di garofano', 'aglio', '1/2', 'cucchiaino', 'macinato', 'cumino', '118', 'g', 'pesto di basilico', '1', 'cucchiaio', 'succo di limone', '2', 'cucchiai', 'acqua']
# ---------------
# 15
# 32 ounces baked beans;6 hot dogs;1 tablespoon horseradish mustard (or yellow);1 cup shredded cheddar cheese;16 ounces sweet potato;tater tots
# ['32', 'ounces', 'baked', 'beans', '6', 'hot dogs', '1', 'tablespoon', 'horseradish mustard', 'yellow', '1', 'cup', 'shredded', 'cheddar cheese', '16', 'ounces', 'sweet', 'potato', 'tater tots']
# 32 once cotto fagioli;6 hot dog;1 cucchiaio senape al rafano (giallo);1 tazza triturati formaggio cheddar;16 once dolce potato;crocchette di patate
# 907 g cotto fagioli;6 hot dog;1 cucchiaio senape al rafano (giallo);236 g triturati formaggio cheddar;453 g dolce potato;crocchette di patate
# ['907', 'g', 'cotto', 'fagioli', '6', 'hot dog', '1', 'cucchiaio', 'senape al rafano', 'giallo', '236', 'g', 'triturati', 'formaggio cheddar', '453', 'g', 'dolce', 'potato', 'crocchette di patate']
# ---------------
# 16
# 4 salmon steaks (each weighing approx. 8 oz);3 tablespoons olive oil;2 tablespoons lemon juice;1 spring onion, minced;6 tablespoons limoncello;1 teaspoon oregano;2 tablespoons minced parsley
# ['4', 'salmon steaks', 'approx. 8', 'oz', '3', 'tablespoons', 'olive oil', '2', 'tablespoons', 'lemon juice', '1', 'spring onion', 'minced', '6', 'tablespoons', 'limoncello', '1', 'teaspoon', 'oregano', '2', 'tablespoons', 'minced', 'parsley']
# 4 bistecche di salmone (circa 8 oz);3 cucchiai olio d'oliva;2 cucchiai succo di limone;1 cipollotto, tritato;6 cucchiai limoncello;1 cucchiaino origano;2 cucchiai tritato prezzemolo
# 4 bistecche di salmone (circa 226 g);3 cucchiai olio d'oliva;2 cucchiai succo di limone;1 cipollotto, tritato;6 cucchiai limoncello;1 cucchiaino origano;2 cucchiai tritato prezzemolo
# ['4', 'bistecche di salmone', 'circa 226', 'g', '3', 'cucchiai', "olio d'oliva", '2', 'cucchiai', 'succo di limone', '1', 'cipollotto', 'tritato', '6', 'cucchiai', 'limoncello', '1', 'cucchiaino', 'origano', '2', 'cucchiai', 'tritato', 'prezzemolo']
# ---------------
# 17
# 1 cup flour;1 1/4 teaspoons baking powder;1/2 teaspoon salt;1/2 cup low-fat cheese, grated;2 tablespoons butter;2/3 cup milk
# ['1', 'cup', 'flour', '1 1/4', 'teaspoons', 'baking powder', '1/2', 'teaspoon', 'salt', '1/2', 'cup', 'low-fat', 'cheese', 'grated', '2', 'tablespoons', 'butter', '2/3', 'cup', 'milk']
# 1 tazza farina;1 1/4 cucchiaini lievito in polvere;1/2 cucchiaino sale;1/2 tazza a basso contenuto di grassi formaggio, grattugiato;2 cucchiai burro;2/3 tazza latte
# 236 g farina;1 1/4 cucchiaini lievito in polvere;1/2 cucchiaino sale;118 g a basso contenuto di grassi formaggio, grattugiato;2 cucchiai burro;157 g latte
# ['236', 'g', 'farina', '1 1/4', 'cucchiaini', 'lievito in polvere', '1/2', 'cucchiaino', 'sale', '118', 'g', 'a basso contenuto di grassi', 'formaggio', 'grattugiato', '2', 'cucchiai', 'burro', '157', 'g', 'latte']
# ---------------
# 18
# 3 stalks celery, sliced;1/2 cucumber, peeled and cubed;1/2 cup coconut water;2 tablespoons jalapeño, seeded and chopped;1/4 teaspoon himalayan sea salt
# ['3', 'stalks', 'celery', 'sliced', '1/2', 'cucumber', 'peeled', 'cubed', '1/2', 'cup', 'coconut water', '2', 'tablespoons', 'jalapeño', 'seeded', 'chopped', '1/4', 'teaspoon', 'himalayan sea salt']
# 3 gambi sedano, affettato;1/2 cetriolo, sbucciato a cubetti;1/2 tazza acqua di cocco;2 cucchiai jalapeño, seminato tritato;1/4 cucchiaino sale marino himalayano
# 3 gambi sedano, affettato;1/2 cetriolo, sbucciato a cubetti;118 g acqua di cocco;2 cucchiai jalapeño, seminato tritato;1/4 cucchiaino sale marino himalayano
# ['3', 'gambi', 'sedano', 'affettato', '1/2', 'cetriolo', 'sbucciato', 'a cubetti', '118', 'g', 'acqua di cocco', '2', 'cucchiai', 'jalapeño', 'seminato', 'tritato', '1/4', 'cucchiaino', 'sale marino himalayano']
# ---------------
# 19
# 1 (15 ounce) can chickpeas, drained;1 lemon, juice of;1/4 cup olive oil;1 garlic clove, peeled;1/8 teaspoon red pepper flakes, crushed
# ['1', '15', 'ounce', 'can', 'chickpeas', 'drained', '1', 'lemon', 'juice of', '1/4', 'cup', 'olive oil', '1', 'garlic', 'clove', 'peeled', '1/8', 'teaspoon', 'red', 'pepper flakes', 'crushed']
# 1 (15 oncia) barattolo ceci, scolato;1 limone, succo di;1/4 tazza olio d'oliva;1 aglio chiodo di garofano, sbucciato;1/8 cucchiaino rosso fiocchi di pepe, schiacciato
# 1 (425 g) barattolo ceci, scolato;1 limone, succo di;59 g olio d'oliva;1 aglio chiodo di garofano, sbucciato;1/8 cucchiaino rosso fiocchi di pepe, schiacciato
# ['1', '425', 'g', 'barattolo', 'ceci', 'scolato', '1', 'limone', 'succo di', '59', 'g', "olio d'oliva", '1', 'aglio', 'chiodo di garofano', 'sbucciato', '1/8', 'cucchiaino', 'rosso', 'fiocchi di pepe', 'schiacciato']
# ---------------
# 20
# 1 bagel;1 egg;1 slice cheddar cheese, kraft singles (other cheese works too);2 2 slices deli ham or 2 slices deli roast beef, any lunch meat
# ['1', 'bagel', '1', 'egg', '1', 'slice', 'cheddar cheese', '2', 'slices', 'deli ham', '2', 'slices', 'deli roast beef', 'any lunch meat']
# 1 bagel;1 uovo;1 fetta formaggio cheddar, 2 fette prosciutto crudo 2 fette arrosto di manzo, qualsiasi carne per il pranzo
# 1 bagel;1 uovo;1 fetta formaggio cheddar, 2 fette prosciutto crudo 2 fette arrosto di manzo, qualsiasi carne per il pranzo
# ['1', 'bagel', '1', 'uovo', '1', 'fetta', 'formaggio cheddar', '2', 'fette', 'prosciutto crudo', '2', 'fette', 'arrosto di manzo', 'qualsiasi carne per il pranzo']
# ---------------
# 21
# 1 cup sugar;2 sticks salted butter (softened);1 teaspoon vinegar;1 teaspoon vanilla;1 1/2 cups all purpose flour;1/2 teaspoon baking soda
# ['1', 'cup', 'sugar', '2', 'sticks', 'salted', 'butter', 'softened', '1', 'teaspoon', 'vinegar', '1', 'teaspoon', 'vanilla', '1 1/2', 'cups', 'all purpose', 'flour', '1/2', 'teaspoon', 'baking soda']
# 1 tazza zucchero;2 bastoncini salato burro (ammorbidito);1 cucchiaino aceto;1 cucchiaino vaniglia;1 1/2 tazze 00 farina;1/2 cucchiaino bicarbonato di sodio
# 236 g zucchero;2 bastoncini salato burro (ammorbidito);1 cucchiaino aceto;1 cucchiaino vaniglia;354 g 00 farina;1/2 cucchiaino bicarbonato di sodio
# ['236', 'g', 'zucchero', '2', 'bastoncini', 'salato', 'burro', 'ammorbidito', '1', 'cucchiaino', 'aceto', '1', 'cucchiaino', 'vaniglia', '354', 'g', '00', 'farina', '1/2', 'cucchiaino', 'bicarbonato di sodio']
# ---------------
# 22
# 1 whole fully cooked bone-in ham (15-18 Pounds);whole cloves;3 cups brown sugar;1/2 cup spicy brown mustard;1 can dr pepper (Or Coke);3 tablespoons apple cider vinegar
# ['1', 'whole', 'fully cooked', 'bone-in', 'ham', '15-18', 'Pounds', 'whole', 'cloves', '3', 'cups', 'brown', 'sugar', '1/2', 'cup', 'spicy', 'brown', 'mustard', '1', 'can', 'dr pepper', 'Coke', '3', 'tablespoons', 'apple cider vinegar']
# 1 intero completamente cotto con osso prosciutto (15-18 Libbre);intero chiodi di garofano;3 tazze marrone zucchero;1/2 tazza piccante marrone senape;1 barattolo Dr Pepper (Coca Cola);3 cucchiai aceto di sidro di mele
# 1 intero completamente cotto con osso prosciutto (15-18 Libbre);intero chiodi di garofano;708 g marrone zucchero;118 g piccante marrone senape;1 barattolo Dr Pepper (Coca Cola);3 cucchiai aceto di sidro di mele
# ['1', 'intero', 'completamente cotto', 'con osso', 'prosciutto', '15-18', 'Libbre', 'intero', 'chiodi di garofano', '708', 'g', 'marrone', 'zucchero', '118', 'g', 'piccante', 'marrone', 'senape', '1', 'barattolo', 'Dr Pepper', 'Coca Cola', '3', 'cucchiai', 'aceto di sidro di mele']
# ---------------
# 23
# 3 ounces chocolate (prepared hot, cooled);0.75 ounces creme de cacao (dark);0.75 ounces vanilla vodka;1 ounce Kahlua;6 mini marshmallows
# ['3', 'ounces', 'chocolate', 'prepared hot', 'cooled', '0.75', 'ounces', 'creme de cacao', 'dark', '0.75', 'ounces', 'vanilla vodka', '1', 'ounce', 'Kahlua', '6', 'mini', 'marshmallows']
# 3 once cioccolato (preparato a caldo, raffreddato);0.75 once crema di cacao (scuro);0.75 once vodka alla vaniglia;1 oncia Kahlua;6 mini marshmallow
# 85 g cioccolato (preparato a caldo, raffreddato);21 g crema di cacao (scuro);21 g vodka alla vaniglia;28 g Kahlua;6 mini marshmallow
# ['85', 'g', 'cioccolato', 'preparato a caldo', 'raffreddato', '21', 'g', 'crema di cacao', 'scuro', '21', 'g', 'vodka alla vaniglia', '28', 'g', 'Kahlua', '6', 'mini', 'marshmallow']
# ---------------
# 24
# 2 cups full-fat greek yogurt;15 saffron strands;1 tablespoon hot water;1/2 cup powdered sugar;1/2 teaspoon ground cardamom;whipped cream, for garnish (optional);crushed nut, for topping (optional)
# ['2', 'cups', 'full-fat', 'greek yogurt', '15', 'saffron', 'strands', '1', 'tablespoon', 'hot', 'water', '1/2', 'cup', 'powdered', 'sugar', '1/2', 'teaspoon', 'ground', 'cardamom', 'whipped', 'cream', 'for garnish', 'crushed', 'nut', 'for topping']
# 2 tazze a base di grassi yogurt greco;15 zafferano filamenti;1 cucchiaio caldo acqua;1/2 tazza in polvere zucchero;1/2 cucchiaino macinato cardamomo;montata crema, per guarnire (schiacciato dado, per la guarnizione (
# 472 g a base di grassi yogurt greco;15 zafferano filamenti;1 cucchiaio caldo acqua;118 g in polvere zucchero;1/2 cucchiaino macinato cardamomo;montata crema, per guarnire (schiacciato dado, per la guarnizione (
# ['472', 'g', 'a base di grassi', 'yogurt greco', '15', 'zafferano', 'filamenti', '1', 'cucchiaio', 'caldo', 'acqua', '118', 'g', 'in polvere', 'zucchero', '1/2', 'cucchiaino', 'macinato', 'cardamomo', 'montata', 'crema', 'per guarnire', 'schiacciato', 'dado', 'per la guarnizione']
# ---------------
# 25
# 1/2 cup instant oatmeal;2 tablespoons freeze-dried blueberry;1 tablespoon slivered almond;1 tablespoon chia seed;1/8 teaspoon vanilla bean;2 teaspoons sugar, of choice;3/4 cup water, or milk, boiling
# ['1/2', 'cup', 'instant', 'oatmeal', '2', 'tablespoons', 'freeze-dried', 'blueberry', '1', 'tablespoon', 'slivered', 'almond', '1', 'tablespoon', 'chia seed', '1/8', 'teaspoon', 'vanilla bean', '2', 'teaspoons', 'sugar', '3/4', 'cup', 'water', 'milk', 'boiling']
# 1/2 tazza istantaneo farina d'avena;2 cucchiai liofilizzato mirtillo;1 cucchiaio affilato mandorla;1 cucchiaio semi di chia;1/8 cucchiaino vanilla bean;2 cucchiaini zucchero, 3/4 tazza acqua, latte, bollente
# 118 g istantaneo farina d'avena;2 cucchiai liofilizzato mirtillo;1 cucchiaio affilato mandorla;1 cucchiaio semi di chia;1/8 cucchiaino vanilla bean;2 cucchiaini zucchero, 177 g acqua, latte, bollente
# ['118', 'g', 'istantaneo', "farina d'avena", '2', 'cucchiai', 'liofilizzato', 'mirtillo', '1', 'cucchiaio', 'affilato', 'mandorla', '1', 'cucchiaio', 'semi di chia', '1/8', 'cucchiaino', 'vanilla bean', '2', 'cucchiaini', 'zucchero', '177', 'g', 'acqua', 'latte', 'bollente']
# ---------------
# 26
# 5 pounds potatoes (cubed);8 eggs (hard boiled & chopped);3 stalks celery (chopped);15 ounces mayo;2 teaspoons salt
# ['5', 'pounds', 'potatoes', 'cubed', '8', 'eggs', 'hard boiled', 'chopped', '3', 'stalks', 'celery', 'chopped', '15', 'ounces', 'mayo', '2', 'teaspoons', 'salt']
# 5 chili patate (a cubetti);8 uova (sodo & tritato);3 gambi sedano (tritato);15 once Maggio;2 cucchiaini sale
# 2,2 kg patate (a cubetti);8 uova (sodo & tritato);3 gambi sedano (tritato);425 g Maggio;2 cucchiaini sale
# ['2,2', 'kg', 'patate', 'a cubetti', '8', 'uova', 'sodo', 'tritato', '3', 'gambi', 'sedano', 'tritato', '425', 'g', 'Maggio', '2', 'cucchiaini', 'sale']
# ---------------
# 27
# 1 cup warm milk, of choice;2 bags chai tea;1 pear, cored and diced;1 tablespoon honey;1/2 teaspoon vanilla extract;1/4 teaspoon cinnamon
# ['1', 'cup', 'warm', 'milk', '2', 'bags', 'chai tea', '1', 'pear', 'cored', 'diced', '1', 'tablespoon', 'honey', '1/2', 'teaspoon', 'vanilla extract', '1/4', 'teaspoon', 'cinnamon']
# 1 tazza caldo latte, 2 borse tè chai;1 pera, senza torsolo a cubetti;1 cucchiaio miele;1/2 cucchiaino estratto di vaniglia;1/4 cucchiaino cannella
# 236 g caldo latte, 2 borse tè chai;1 pera, senza torsolo a cubetti;1 cucchiaio miele;1/2 cucchiaino estratto di vaniglia;1/4 cucchiaino cannella
# ['236', 'g', 'caldo', 'latte', '2', 'borse', 'tè chai', '1', 'pera', 'senza torsolo', 'a cubetti', '1', 'cucchiaio', 'miele', '1/2', 'cucchiaino', 'estratto di vaniglia', '1/4', 'cucchiaino', 'cannella']
# ---------------
# 28
# 1/4 cup strawberry, sliced;1 cup water;1 cup whole milk
# ['1/4', 'cup', 'strawberry', 'sliced', '1', 'cup', 'water', '1', 'cup', 'whole', 'milk']
# 1/4 tazza fragola, affettato;1 tazza acqua;1 tazza intero latte
# 59 g fragola, affettato;236 g acqua;236 g intero latte
# ['59', 'g', 'fragola', 'affettato', '236', 'g', 'acqua', '236', 'g', 'intero', 'latte']
# ---------------
# 29
# 4 cups rolled oats;2 tablespoons seeds (chia, these are optional, I just love the texture they give);1/2 cup peanuts (unsalted, chopped);3/4 cup natural peanut butter (melted);1/2 cup brown rice syrup (honey works too!)
# ['4', 'cups', 'rolled oats', '2', 'tablespoons', 'seeds', '1/2', 'cup', 'peanuts', 'unsalted', 'chopped', '3/4', 'cup', 'natural', 'peanut butter', 'melted', '1/2', 'cup', 'brown rice syrup', 'honey']
# 4 tazze fiocchi d'avena;2 cucchiai Semi (1/2 tazza arachidi (non salato, tritato);3/4 tazza naturale burro di arachidi (fuso);1/2 tazza sciroppo di riso integrale (miele
# 944 g fiocchi d'avena;2 cucchiai Semi (118 g arachidi (non salato, tritato);177 g naturale burro di arachidi (fuso);118 g sciroppo di riso integrale (miele
# ['944', 'g', "fiocchi d'avena", '2', 'cucchiai', 'Semi', '118', 'g', 'arachidi', 'non salato', 'tritato', '177', 'g', 'naturale', 'burro di arachidi', 'fuso', '118', 'g', 'sciroppo di riso integrale', 'miele']
# ---------------
# 30
# 3 cups half-and-half;1 (14 ounce) can sweetened condensed milk (NOT evaporated milk);1 cup mashed banana;1 tablespoon vanilla extract;1 teaspoon ground cinnamon
# ['3', 'cups', 'half-and-half', '1', '14', 'ounce', 'can', 'sweetened', 'condensed', 'milk', '1', 'cup', 'mashed', 'banana', '1', 'tablespoon', 'vanilla extract', '1', 'teaspoon', 'ground', 'cinnamon']
# 3 tazze metà e metà;1 (14 oncia) barattolo addolcito condensato latte (1 tazza purè banana;1 cucchiaio estratto di vaniglia;1 cucchiaino macinato cannella
# 708 g metà e metà;1 (396 g) barattolo addolcito condensato latte (236 g purè banana;1 cucchiaio estratto di vaniglia;1 cucchiaino macinato cannella
# ['708', 'g', 'metà e metà', '1', '396', 'g', 'barattolo', 'addolcito', 'condensato', 'latte', '236', 'g', 'purè', 'banana', '1', 'cucchiaio', 'estratto di vaniglia', '1', 'cucchiaino', 'macinato', 'cannella']
# ---------------
# 31
# 1 banana;1 maraschino cherry;1 (7 ounce) canned whipped cream (I use low-fat Redi-Whip)
# ['1', 'banana', '1', 'maraschino cherry', '1', '7', 'ounce', 'canned', 'whipped', 'cream']
# 1 banana;1 maraschino cherry;1 (7 oncia) in scatola montata crema (
# 1 banana;1 maraschino cherry;1 (198 g) in scatola montata crema (
# ['1', 'banana', '1', 'maraschino cherry', '1', '198', 'g', 'in scatola', 'montata', 'crema']
# ---------------
# 32
# 2 slices bread;1 slice American cheese;1 tablespoon mayonnaise
# ['2', 'slices', 'bread', '1', 'slice', 'American cheese', '1', 'tablespoon', 'mayonnaise']
# 2 fette pane;1 fetta Formaggio americano;1 cucchiaio maionese
# 2 fette pane;1 fetta Formaggio americano;1 cucchiaio maionese
# ['2', 'fette', 'pane', '1', 'fetta', 'Formaggio americano', '1', 'cucchiaio', 'maionese']
# ---------------
# 33
# 2 cups watermelon;3 tablespoons sugar;8 mint leaves;3 tablespoons lemon juice;3 ice cubes
# ['2', 'cups', 'watermelon', '3', 'tablespoons', 'sugar', '8', 'mint', 'leaves', '3', 'tablespoons', 'lemon juice', '3', 'ice cubes']
# 2 tazze anguria;3 cucchiai zucchero;8 come foglie;3 cucchiai succo di limone;3 cubetti di ghiaccio
# 472 g anguria;3 cucchiai zucchero;8 menta foglie;3 cucchiai succo di limone;3 cubetti di ghiaccio
# ['472', 'g', 'anguria', '3', 'cucchiai', 'zucchero', '8', 'menta', 'foglie', '3', 'cucchiai', 'succo di limone', '3', 'cubetti di ghiaccio']
# ---------------
# 34
# 2 ounces unsweetened baking chocolate;14 ounces sweetened condensed milk;4 cups water;1 teaspoon vanilla
# ['2', 'ounces', 'unsweetened', 'baking chocolate', '14', 'ounces', 'sweetened', 'condensed', 'milk', '4', 'cups', 'water', '1', 'teaspoon', 'vanilla']
# 2 once non zuccherato cioccolato da forno;14 once addolcito condensato latte;4 tazze acqua;1 cucchiaino vaniglia
# 56 g non zuccherato cioccolato da forno;396 g addolcito condensato latte;944 g acqua;1 cucchiaino vaniglia
# ['56', 'g', 'non zuccherato', 'cioccolato da forno', '396', 'g', 'addolcito', 'condensato', 'latte', '944', 'g', 'acqua', '1', 'cucchiaino', 'vaniglia']
# ---------------
# 35
# 8 slices bacon;1 large onion, chopped;2 (16 ounce) bags frozen cut okra (or 2lb. fresh okra, sliced into 1/2 inch pieces);2 (14 ounce) cans diced tomatoes, undrained;salt and pepper
# ['8', 'slices', 'bacon', '1', 'large', 'onion', 'chopped', '2', '16', 'ounce', 'bags', 'frozen', 'cut', 'okra', '2', 'lb.', 'fresh', 'okra', 'sliced into 1/2 inch pieces', '2', '14', 'ounce', 'cans', 'diced', 'tomatoes', 'undrained', 'salt', 'pepper']
# 8 fette pancetta;1 grande cipolla, tritato;2 (16 oncia) borse congelato taglio gombo (2 lb. fresco gombo, tagliato a fette di 1/2 pollice);2 (14 oncia) lattine a cubetti pomodori, non scolato;sale pepe
# 8 fette pancetta;1 grande cipolla, tritato;2 (453 g) borse congelato taglio gombo (0,9 kg fresco gombo, tagliato a fette di 1,3 cm);2 (396 g) lattine a cubetti pomodori, non scolato;sale pepe
# ['8', 'fette', 'pancetta', '1', 'grande', 'cipolla', 'tritato', '2', '453', 'g', 'borse', 'congelato', 'taglio', 'gombo', '0,9', 'kg', 'fresco', 'gombo', 'tagliato a fette di 1,3 cm', '2', '396', 'g', 'lattine', 'a cubetti', 'pomodori', 'non scolato', 'sale', 'pepe']
# ---------------
# 36
# 4 cups flour;1/2 teaspoon salt;1 teaspoon baking soda;1 3/4 cups milk
# ['4', 'cups', 'flour', '1/2', 'teaspoon', 'salt', '1', 'teaspoon', 'baking soda', '1 3/4', 'cups', 'milk']
# 4 tazze farina;1/2 cucchiaino sale;1 cucchiaino bicarbonato di sodio;1 3/4 tazze latte
# 944 g farina;1/2 cucchiaino sale;1 cucchiaino bicarbonato di sodio;413 g latte
# ['944', 'g', 'farina', '1/2', 'cucchiaino', 'sale', '1', 'cucchiaino', 'bicarbonato di sodio', '413', 'g', 'latte']
# ---------------
# 37
# 3 lettuces (butter);20 milliliters red wine vinegar;2 teaspoons Dijon mustard;80 milliliters extra virgin olive oil;1/4 cup sliced green olives (pitted);1/4 cup sliced black olives (pitted);2 vine ripened tomatoes (de-seeded, chopped)
# ['3', 'lettuces', 'butter', '20', 'milliliters', 'red wine vinegar', '2', 'teaspoons', 'Dijon mustard', '80', 'milliliters', 'extra virgin', 'olive oil', '1/4', 'cup', 'sliced', 'green', 'olives', 'pitted', '1/4', 'cup', 'sliced', 'black', 'olives', 'pitted', '2', 'vine', 'ripened', 'tomatoes', 'de-seeded', 'chopped']
# 3 lattughe (burro);20 millilitri aceto di vino rosso;2 cucchiaini Senape di Digione;80 millilitri extra vergine olio d'oliva;1/4 tazza affettato verde olive (snocciolato);1/4 tazza affettato nero olive (snocciolato);2 vite maturato pomodori (de-seminato, tritato)
# 3 lattughe (burro);20 millilitri aceto di vino rosso;2 cucchiaini Senape di Digione;80 millilitri extra vergine olio d'oliva;59 g affettato verde olive (snocciolato);59 g affettato nero olive (snocciolato);2 vite maturato pomodori (de-seminato, tritato)
# ['3', 'lattughe', 'burro', '20', 'millilitri', 'aceto di vino rosso', '2', 'cucchiaini', 'Senape di Digione', '80', 'millilitri', 'extra vergine', "olio d'oliva", '59', 'g', 'affettato', 'verde', 'olive', 'snocciolato', '59', 'g', 'affettato', 'nero', 'olive', 'snocciolato', '2', 'vite', 'maturato', 'pomodori', 'de-seminato', 'tritato']
# ---------------
# 38
# 2 large fresh tomatoes (I like creole and beefsteak) or 2 lbs cherry tomatoes;1 1/2 cups fresh corn or 1 1/2 cups frozen corn, blanched and drained;8 fresh basil leaves;balsamic vinegar;extra virgin olive oil
# ['2', 'large', 'fresh', 'tomatoes', '2', 'lbs', 'cherry tomatoes', '1 1/2', 'cups', 'fresh', 'corn', '1 1/2', 'cups', 'frozen', 'corn', 'blanched', 'drained', '8', 'fresh', 'basil', 'leaves', 'balsamic vinegar', 'extra virgin', 'olive oil']
# 2 grande fresco pomodori (2 libbre pomodori ciliegia;1 1/2 tazze fresco mais 1 1/2 tazze congelato mais, scottato scolato;8 fresco basilico foglie;aceto balsamico;extra vergine olio d'oliva
# 2 grande fresco pomodori (0,9 kg pomodori ciliegia;354 g fresco mais 354 g congelato mais, scottato scolato;8 fresco basilico foglie;aceto balsamico;extra vergine olio d'oliva
# ['2', 'grande', 'fresco', 'pomodori', '0,9', 'kg', 'pomodori ciliegia', '354', 'g', 'fresco', 'mais', '354', 'g', 'congelato', 'mais', 'scottato', 'scolato', '8', 'fresco', 'basilico', 'foglie', 'aceto balsamico', 'extra vergine', "olio d'oliva"]
# ---------------
# 39
# 2 slices sandwich bread (I prefer whole wheat);2 slices swiss cheese;2 ounces thinly sliced ham;2 pineapple slices, cored (thin slices);3 fresh basil leaves;1 tablespoon butter
# ['2', 'slices', 'sandwich bread', 'whole wheat)', '2', 'slices', 'swiss cheese', '2', 'ounces', 'thinly sliced', 'ham', '2', 'pineapple slices', 'cored', 'thin', '3', 'fresh', 'basil', 'leaves', '1', 'tablespoon', 'butter']
# 2 fette pane per tramezzini (integrale);2 fette formaggio svizzero;2 once a fette sottili prosciutto;2 fette di ananas, senza torsolo (sottile 3 fresco basilico foglie;1 cucchiaio burro
# 2 fette pane per tramezzini (integrale);2 fette formaggio svizzero;56 g a fette sottili prosciutto;2 fette di ananas, senza torsolo (sottile 3 fresco basilico foglie;1 cucchiaio burro
# ['2', 'fette', 'pane per tramezzini', 'integrale)', '2', 'fette', 'formaggio svizzero', '56', 'g', 'a fette sottili', 'prosciutto', '2', 'fette di ananas', 'senza torsolo', 'sottile', '3', 'fresco', 'basilico', 'foglie', '1', 'cucchiaio', 'burro']
# ---------------
# 40
# 3 tablespoons kosher salt (must be kosher!);1 1/2 tablespoons brown sugar;1 orange zested;1 teaspoon black pepper;1 tablespoon fresh thyme leaves;12 pounds turkey (completely defrosted)
# ['3', 'tablespoons', 'kosher', 'salt', '1 1/2', 'tablespoons', 'brown', 'sugar', '1', 'orange', 'zested', '1', 'teaspoon', 'black', 'pepper', '1', 'tablespoon', 'fresh', 'thyme leaves', '12', 'pounds', 'turkey', 'completely defrosted']
# 3 cucchiai kosher sale (1 1/2 cucchiai marrone zucchero;1 arancione zestato;1 cucchiaino nero pepe;1 cucchiaio fresco foglie di timo;12 chili tacchino (completamente scongelato)
# 3 cucchiai kosher sale (1 1/2 cucchiai marrone zucchero;1 arancione zestato;1 cucchiaino nero pepe;1 cucchiaio fresco foglie di timo;5,4 kg tacchino (completamente scongelato)
# ['3', 'cucchiai', 'kosher', 'sale', '1 1/2', 'cucchiai', 'marrone', 'zucchero', '1', 'arancione', 'zestato', '1', 'cucchiaino', 'nero', 'pepe', '1', 'cucchiaio', 'fresco', 'foglie di timo', '5,4', 'kg', 'tacchino', 'completamente scongelato']
# ---------------
# 41
# 1 box cake mix (prepared per package instructions);8 ounces cream cheese (type cake icing);1 bag chocolates (white melting);candy sprinkles
# ['1', 'box', 'cake mix', 'prepared per package instructions', '8', 'ounces', 'cream cheese', 'cake icing', '1', 'bag', 'chocolates', 'white', 'melting', 'candy sprinkles']
# 1 scatola impasto per torte (preparato secondo le istruzioni della confezione);8 once crema di formaggio (glassa per torte);1 borsa cioccolatini (bianco fusione);zuccherini
# 1 scatola impasto per torte (preparato secondo le istruzioni della confezione);226 g crema di formaggio (glassa per torte);1 borsa cioccolatini (bianco fusione);zuccherini
# ['1', 'scatola', 'impasto per torte', 'preparato secondo le istruzioni della confezione', '226', 'g', 'crema di formaggio', 'glassa per torte', '1', 'borsa', 'cioccolatini', 'bianco', 'fusione', 'zuccherini']
# ---------------
# 42
# 1 cup all purpose flour;1 1/2 teaspoons baking powder;1 cup butter (softened);1 cup confectioners' sugar;2 eggs (room temperature);1 teaspoon vanilla extract;1/2 cup milk (room temperature)
# ['1', 'cup', 'all purpose flour', '1 1/2', 'teaspoons', 'baking powder', '1', 'cup', 'butter', 'softened', '1', 'cup', "confectioners' sugar", '2', 'eggs', 'room temperature', '1', 'teaspoon', 'vanilla extract', '1/2', 'cup', 'milk', 'room temperature']
# 1 tazza farina 00;1 1/2 cucchiaini lievito in polvere;1 tazza burro (ammorbidito);1 tazza zucchero a velo;2 uova (temperatura ambiente);1 cucchiaino estratto di vaniglia;1/2 tazza latte (temperatura ambiente)
# 236 g farina 00;1 1/2 cucchiaini lievito in polvere;236 g burro (ammorbidito);236 g zucchero a velo;2 uova (temperatura ambiente);1 cucchiaino estratto di vaniglia;118 g latte (temperatura ambiente)
# ['236', 'g', 'farina 00', '1 1/2', 'cucchiaini', 'lievito in polvere', '236', 'g', 'burro', 'ammorbidito', '236', 'g', 'zucchero a velo', '2', 'uova', 'temperatura ambiente', '1', 'cucchiaino', 'estratto di vaniglia', '118', 'g', 'latte', 'temperatura ambiente']
# ---------------
# 43
# 1 cup mayonnaise;4 green onions (chopped);6 ounces cheddar cheese (shredded);12 ounces bacon (cooked & crubled);3 ounces slivered almonds
# ['4', 'green', 'onions', 'chopped', '6', 'ounces', 'cheddar cheese', 'shredded', '12', 'ounces', 'bacon', 'cooked', 'crubled', '3', 'ounces', 'slivered', 'almonds']
# 4 verde cipolle (tritato);6 once formaggio cheddar (triturati);12 once pancetta (cotto & increspato);3 once affilato mandorle
# 4 verde cipolle (tritato);170 g formaggio cheddar (triturati);340 g pancetta (cotto & increspato);85 g affilato mandorle
# ['4', 'verde', 'cipolle', 'tritato', '170', 'g', 'formaggio cheddar', 'triturati', '340', 'g', 'pancetta', 'cotto', 'increspato', '85', 'g', 'affilato', 'mandorle']
# ---------------
# 44
# 6 tablespoons butter (melted);3 cups powdered sugar;2 teaspoons vanilla;3 tablespoons heavy cream ({can substitute milk})
# ['6', 'tablespoons', 'butter', 'melted', '3', 'cups', 'powdered', 'sugar', '2', 'teaspoons', 'vanilla', '3', 'tablespoons', 'heavy cream']
# 6 cucchiai burro (fuso);3 tazze in polvere zucchero;2 cucchiaini vaniglia;3 cucchiai panna pesante ({
# 6 cucchiai burro (fuso);708 g in polvere zucchero;2 cucchiaini vaniglia;3 cucchiai panna pesante ({
# ['6', 'cucchiai', 'burro', 'fuso', '708', 'g', 'in polvere', 'zucchero', '2', 'cucchiaini', 'vaniglia', '3', 'cucchiai', 'panna pesante']
# ---------------
# 45
# 1 tablespoon butter or 1 tablespoon margarine;4 boneless skinless chicken breast halves;1 (6 ounce) box chicken flavor stuffing mix;1 (10 3/4 ounce) can mushroom soup or (10 3/4 ounce) can 98% fat-free cream of mushroom soup;1/2 cup milk;1/2 cup shredded cheddar cheese;2 cups cooked vegetables
# ['1', 'tablespoon', 'butter', '1', 'tablespoon', 'margarine', '4', 'boneless', 'skinless', 'chicken', 'breast halves', '1', '6', 'ounce', 'box', 'chicken flavor stuffing mix', '1', '10 3/4', 'ounce', 'can', 'mushroom soup', '10 3/4', 'ounce', 'can', 'cream of mushroom soup', '1/2', 'cup', 'milk', '1/2', 'cup', 'shredded', 'cheddar cheese', '2', 'cups', 'cooked', 'vegetables']
# 1 cucchiaio burro 1 cucchiaio margarina;4 disossato senza pelle pollo metà del seno;1 (6 oncia) scatola mix di ripieno al gusto di pollo;1 (10 3/4 oncia) barattolo zuppa di funghi 10 3/4 oncia) barattolo crema di funghi;1/2 tazza latte;1/2 tazza triturati formaggio cheddar;2 tazze cotto verdure
# 1 cucchiaio burro 1 cucchiaio margarina;4 disossato senza pelle pollo metà del seno;1 (170 g) scatola mix di ripieno al gusto di pollo;1 (304 g) barattolo zuppa di funghi 304 g) barattolo crema di funghi;118 g latte;118 g triturati formaggio cheddar;472 g cotto verdure
# ['1', 'cucchiaio', 'burro', '1', 'cucchiaio', 'margarina', '4', 'disossato', 'senza pelle', 'pollo', 'metà del seno', '1', '170', 'g', 'scatola', 'mix di ripieno al gusto di pollo', '1', '304', 'g', 'barattolo', 'zuppa di funghi', '304', 'g', 'barattolo', 'crema di funghi', '118', 'g', 'latte', '118', 'g', 'triturati', 'formaggio cheddar', '472', 'g', 'cotto', 'verdure']
# ---------------
# 46
# 2 eggs (at room temperature);salt;pepper;1 tablespoon clarified butter;chives (Pinch of chopped, for garnish, optional)
# ['2', 'eggs', 'room temperature', 'salt', 'pepper', '1', 'tablespoon', 'clarified butter', 'chives', 'Pinch of', 'chopped', 'for garnish']
# 2 uova (temperatura ambiente);sale;pepe;1 cucchiaio burro chiarificato;erba cipollina (Pizzico di tritato, per guarnire,
# 2 uova (temperatura ambiente);sale;pepe;1 cucchiaio burro chiarificato;erba cipollina (Pizzico di tritato, per guarnire,
# ['2', 'uova', 'temperatura ambiente', 'sale', 'pepe', '1', 'cucchiaio', 'burro chiarificato', 'erba cipollina', 'Pizzico di', 'tritato', 'per guarnire']
# ---------------
# 47
# 1 package chocolate cake mix;3/4 cup marshmallow;3/4 cup graham cracker, crushed;1/2 cup oil;2 eggs
# ['1', 'package', 'chocolate cake mix', '3/4', 'cup', 'marshmallow', '3/4', 'cup', 'graham cracker', 'crushed', '1/2', 'cup', 'oil', '2', 'eggs']
# 1 pacchetto impasto per torta al cioccolato;3/4 tazza marshmallow;3/4 tazza cracker graham, schiacciato;1/2 tazza olio;2 uova
# 1 pacchetto impasto per torta al cioccolato;177 g marshmallow;177 g cracker graham, schiacciato;118 g olio;2 uova
# ['1', 'pacchetto', 'impasto per torta al cioccolato', '177', 'g', 'marshmallow', '177', 'g', 'cracker graham', 'schiacciato', '118', 'g', 'olio', '2', 'uova']
# ---------------
# 48
# 3 quarts popped popcorn, remove unpopped kernels;3/4 cup butter;1/4 cup vegetable oil;1 (16 ounce) bag miniature marshmallows;1 (8 ounce) container roasted unsalted peanuts;1 (16 ounce) bag M&M's plain chocolate candy (I use orange and black candy corn for Halloween and no nuts.)
# ['3', 'quarts', 'popped', 'popcorn', 'remove unpopped kernels', '3/4', 'cup', 'butter', '1/4', 'cup', 'oil', '1', '16', 'ounce', 'bag', 'miniature', 'marshmallows', '1', '8', 'ounce', 'container', 'roasted', 'unsalted', 'peanuts', '1', '16', 'ounce', 'bag', 'plain chocolate candy']
# 3 quartini scoppiato popcorn, rimuovere i chicchi non spuntati;3/4 tazza burro;1/4 tazza olio;1 (16 oncia) borsa mini marshmallow;1 (8 oncia) contenitore arrostito non salato arachidi;1 (16 oncia) borsa caramelle al cioccolato fondente (
# 3 quartini scoppiato popcorn, rimuovere i chicchi non spuntati;177 g burro;59 g olio;1 (453 g) borsa mini marshmallow;1 (226 g) contenitore arrostito non salato arachidi;1 (453 g) borsa caramelle al cioccolato fondente (
# ['3', 'quartini', 'scoppiato', 'popcorn', 'rimuovere i chicchi non spuntati', '177', 'g', 'burro', '59', 'g', 'olio', '1', '453', 'g', 'borsa', 'mini', 'marshmallow', '1', '226', 'g', 'contenitore', 'arrostito', 'non salato', 'arachidi', '1', '453', 'g', 'borsa', 'caramelle al cioccolato fondente']
# ---------------
# 49
# 1 onion (medium, sliced);1 apple (medium, sliced);1 head red cabbage (shredded);1/3 cup sugar;1/3 cup white vinegar;1/2 teaspoon salt;1/4 teaspoon pepper
# ['1', 'onion', 'medium', 'sliced', '1', 'apple', 'medium', 'sliced', '1', 'head', 'red', 'cabbage', 'shredded', '1/3', 'cup', 'sugar', '1/3', 'cup', 'white', 'vinegar', '1/2', 'teaspoon', 'salt', '1/4', 'teaspoon', 'pepper']
# 1 cipolla (medio, affettato);1 mela (medio, affettato);1 testa rosso cavolo (triturati);1/3 tazza zucchero;1/3 tazza bianco aceto;1/2 cucchiaino sale;1/4 cucchiaino pepe
# 1 cipolla (medio, affettato);1 mela (medio, affettato);1 testa rosso cavolo (triturati);78 g zucchero;78 g bianco aceto;1/2 cucchiaino sale;1/4 cucchiaino pepe
# ['1', 'cipolla', 'medio', 'affettato', '1', 'mela', 'medio', 'affettato', '1', 'testa', 'rosso', 'cavolo', 'triturati', '78', 'g', 'zucchero', '78', 'g', 'bianco', 'aceto', '1/2', 'cucchiaino', 'sale', '1/4', 'cucchiaino', 'pepe']
# ---------------
# 50
# 2 pounds flank steak;1 lime;3 tablespoons steak seasoning (Canadian);2 tablespoons olive oil
# ['2', 'pounds', 'flank steak', '1', 'lime', '3', 'tablespoons', 'steak seasoning', '2', 'tablespoons', 'olive oil']
# 2 chili bistecca di fianchetto;1 lime;3 cucchiai condimento per bistecche (2 cucchiai olio d'oliva
# 0,9 kg bistecca di fianchetto;1 lime;3 cucchiai condimento per bistecche (2 cucchiai olio d'oliva
# ['0,9', 'kg', 'bistecca di fianchetto', '1', 'lime', '3', 'cucchiai', 'condimento per bistecche', '2', 'cucchiai', "olio d'oliva"]
# ---------------
# 51
# 3/4 cup arrowroot powder;1 1/2 cups vegan milk (almond or coconut);1 tablespoon baking powder;1/4 teaspoon sea salt;4 eggs;2 tablespoons coconut oil (melted, + more for cooking);3 drops liquid stevia (optional)
# ['3/4', 'cup', 'arrowroot powder', '1 1/2', 'cups', 'milk', '1', 'tablespoon', 'baking powder', '1/4', 'teaspoon', 'sea salt', '4', 'eggs', '2', 'tablespoons', 'coconut oil', 'melted', 'more', 'for cooking', '3', 'drops', 'liquid', 'stevia']
# 3/4 tazza polvere di arrowroot;1 1/2 tazze latte (1 cucchiaio lievito in polvere;1/4 cucchiaino sale marino;4 uova;2 cucchiai olio di cocco (fuso, + di più per la cottura);3 gocce liquido stevia (
# 177 g polvere di arrowroot;354 g latte (1 cucchiaio lievito in polvere;1/4 cucchiaino sale marino;4 uova;2 cucchiai olio di cocco (fuso, + di più per la cottura);3 gocce liquido stevia (
# ['177', 'g', 'polvere di arrowroot', '354', 'g', 'latte', '1', 'cucchiaio', 'lievito in polvere', '1/4', 'cucchiaino', 'sale marino', '4', 'uova', '2', 'cucchiai', 'olio di cocco', 'fuso', 'di più', 'per la cottura', '3', 'gocce', 'liquido', 'stevia']
# ---------------
# 52
# 8 slices whole grain bread;8 slices provolone cheese;2 tablespoons Tabasco;4 tablespoons pesto sauce;4 ounces spinach (fresh organic);2 tablespoons olive oil
# ['8', 'slices', 'whole grain bread', '8', 'slices', 'provolone cheese', '2', 'tablespoons', 'Tabasco', '4', 'tablespoons', 'pesto sauce', '4', 'ounces', 'spinach', 'fresh', '2', 'tablespoons', 'olive oil']
# 8 fette pane integrale;8 fette provolone cheese;2 cucchiai Tabasco;4 cucchiai salsa al pesto;4 once spinaci (fresco 2 cucchiai olio d'oliva
# 8 fette pane integrale;8 fette provolone cheese;2 cucchiai Tabasco;4 cucchiai salsa al pesto;113 g spinaci (fresco 2 cucchiai olio d'oliva
# ['8', 'fette', 'pane integrale', '8', 'fette', 'provolone cheese', '2', 'cucchiai', 'Tabasco', '4', 'cucchiai', 'salsa al pesto', '113', 'g', 'spinaci', 'fresco', '2', 'cucchiai', "olio d'oliva"]
# ---------------
# 53
# 1 3/4 cups crushed graham cracker crumbs;1/3 cup sugar;1/4 cup melted butter;2 cups whipped cream whipped topping (1 envelope);1/2 teaspoon vanilla;1 (8 ounce) package cream cheese, softened;1 (28 ounce) can cherry pie filling
# ['1 3/4', 'cups', 'crushed', 'graham cracker crumbs', '1/3', 'cup', 'sugar', '1/4', 'cup', 'melted', 'butter', '2', 'cups', 'whipped cream whipped topping', '1', 'envelope', '1/2', 'teaspoon', 'vanilla', '1', '8', 'ounce', 'package', 'cream cheese', 'softened', '1', '28', 'ounce', 'can', 'cherry pie filling']
# 1 3/4 tazze schiacciato briciole di cracker Graham;1/3 tazza zucchero;1/4 tazza fuso burro;2 tazze panna montato guarnizione montata (1 busta);1/2 cucchiaino vaniglia;1 (8 oncia) pacchetto crema di formaggio, ammorbidito;1 (28 oncia) barattolo ripieno di torta di ciliegie
# 413 g schiacciato briciole di cracker Graham;78 g zucchero;59 g fuso burro;472 g panna montato guarnizione montata (1 busta);1/2 cucchiaino vaniglia;1 (226 g) pacchetto crema di formaggio, ammorbidito;1 (793 g) barattolo ripieno di torta di ciliegie
# ...
# 1 cucchiaio olio di cartamo;6 medio zucchini (circa 1 pollice di diametro e 6-8 pollici di lunghezza; 2 chili);8 extra large uova;8 once formaggio feta (sbriciolato);1/2 tazza parmigiano reggiano cheese (grattugiato);8 once formaggio cheddar (grattugiato affilato);1/2 tazza farina di matzoh
# 1 cucchiaio olio di cartamo;6 medio zucchini (circa 2,5 cm di diametro e 15 - 20 cm di lunghezza; 0,9 kg);8 extra large uova;226 g formaggio feta (sbriciolato);118 g parmigiano reggiano cheese (grattugiato);226 g formaggio cheddar (grattugiato affilato);118 g farina di matzoh
# ['1', 'cucchiaio', 'olio di cartamo', '6', 'medio', 'zucchini', 'circa 2,5 cm di diametro e 15 - 20 cm di lunghezza', '0,9', 'kg', '8', 'extra large', 'uova', '226', 'g', 'formaggio feta', 'sbriciolato', '118', 'g', 'parmigiano reggiano cheese', 'grattugiato', '226', 'g', 'formaggio cheddar', 'grattugiato affilato', '118', 'g', 'farina di matzoh']
# ---------------
# 681
# 2 cups instant rice;2 cups water;3 tablespoons taco seasoning;1 (7 ounce) can rotel;1 (6 ounce) can tomato sauce
# ['2', 'cups', 'instant', 'rice', '2', 'cups', 'water', '3', 'tablespoons', 'taco seasoning', '1', '7', 'ounce', 'can', 'rotel', '1', '6', 'ounce', 'can', 'tomato sauce']
# 2 tazze istantaneo rice;2 tazze acqua;3 cucchiai condimento per taco;1 (7 oncia) barattolo rotel;1 (6 oncia) barattolo salsa di pomodoro
# 472 g istantaneo rice;472 g acqua;3 cucchiai condimento per taco;1 (198 g) barattolo rotel;1 (170 g) barattolo salsa di pomodoro
# ['472', 'g', 'istantaneo', 'rice', '472', 'g', 'acqua', '3', 'cucchiai', 'condimento per taco', '1', '198', 'g', 'barattolo', 'rotel', '1', '170', 'g', 'barattolo', 'salsa di pomodoro']
# ---------------
# 682
# 1 (7 1/4 ounce) bottle Smucker’s® Magic Shell ® Chocolate Pretzel Flavored Topping, flavored topping;1/2 cup salted peanuts (cocktail);chocolate or caramel ice cream
# ['1', '7 1/4', 'ounce', 'bottle', 'flavored topping', '1/2', 'cup', 'salted peanuts', 'cocktail', 'chocolate', 'caramel', 'ice cream']
# 1 (7 1/4 oncia) bottiglia guarnizione aromatizzata;1/2 tazza arachidi salate (cocktail);cioccolato caramello gelato
# 1 (205,1 g) bottiglia guarnizione aromatizzata;118 g arachidi salate (cocktail);cioccolato caramello gelato
# ['1', '205,1', 'g', 'bottiglia', 'guarnizione aromatizzata', '118', 'g', 'arachidi salate', 'cocktail', 'cioccolato', 'caramello', 'gelato']
# ---------------
# 683
# 4 cucumbers;1/4 cup mustard;1/4 cup mayonnaise;8 slices roast beef;4 slices turkey;4 slices ham;8 slices cheddar cheese
# ['4', 'cucumbers', '1/4', 'cup', 'mustard', '1/4', 'cup', 'mayonnaise', '8', 'slices', 'roast beef', '4', 'slices', 'turkey', '4', 'slices', 'ham', '8', 'slices', 'cheddar cheese']
# 4 cetrioli;1/4 tazza senape;1/4 tazza maionese;8 fette arrosto di manzo;4 fette tacchino;4 fette prosciutto;8 fette formaggio cheddar
# 4 cetrioli;59 g senape;59 g maionese;8 fette arrosto di manzo;4 fette tacchino;4 fette prosciutto;8 fette formaggio cheddar
# ['4', 'cetrioli', '59', 'g', 'senape', '59', 'g', 'maionese', '8', 'fette', 'arrosto di manzo', '4', 'fette', 'tacchino', '4', 'fette', 'prosciutto', '8', 'fette', 'formaggio cheddar']
# ---------------
# 684
# 3 large egg whites;1/2 cup sugar;1/2 teaspoon vanilla extract;1/4 teaspoon kosher salt;14 ounces sweetened shredded coconut
# ['3', 'large', 'egg', 'whites', '1/2', 'cup', 'sugar', '1/2', 'teaspoon', 'vanilla extract', '1/4', 'teaspoon', 'kosher salt', '14', 'ounces', 'sweetened', 'shredded', 'coconut']
# 3 grande uovo bianchi;1/2 tazza zucchero;1/2 cucchiaino estratto di vaniglia;1/4 cucchiaino sale kosher;14 once addolcito triturati noce di cocco
# 3 grande uovo bianchi;118 g zucchero;1/2 cucchiaino estratto di vaniglia;1/4 cucchiaino sale kosher;396 g addolcito triturati noce di cocco
# ['3', 'grande', 'uovo', 'bianchi', '118', 'g', 'zucchero', '1/2', 'cucchiaino', 'estratto di vaniglia', '1/4', 'cucchiaino', 'sale kosher', '396', 'g', 'addolcito', 'triturati', 'noce di cocco']
# ---------------
# 685
# 1 pound boneless pork loin roast (cut into thin strips);1 green bell pepper (cut into thin strips);3/4 cup salsa;4 flour tortillas (8-10 inches);1 cup cheddar cheese (shredded);fresh cilantro (optional);parsley (optional)
# ['1', 'pound', 'boneless', 'pork loin roast', 'cut into thin strips', '1', 'green', 'bell pepper', 'cut into thin strips', '3/4', 'cup', 'salsa', '4', 'flour tortillas', '8-10', 'inches', '1', 'cup', 'cheddar cheese', 'shredded', 'fresh', 'cilantro', 'parsley']
# 1 sterlina disossato arrosto di lonza di maiale (tagliato a strisce sottili);1 verde peperone (tagliato a strisce sottili);3/4 tazza salsa;4 tortillas di farina (8-10 pollici);1 tazza formaggio cheddar (triturati);fresco coriandolo (prezzemolo (
# 1 sterlina disossato arrosto di lonza di maiale (tagliato a strisce sottili);1 verde peperone (tagliato a strisce sottili);177 g salsa;4 tortillas di farina (20 - 25 cm);236 g formaggio cheddar (triturati);fresco coriandolo (prezzemolo (
# ['1', 'sterlina', 'disossato', 'arrosto di lonza di maiale', 'tagliato a strisce sottili', '1', 'verde', 'peperone', 'tagliato a strisce sottili', '177', 'g', 'salsa', '4', 'tortillas di farina', '20 - 25', 'cm', '236', 'g', 'formaggio cheddar', 'triturati', 'fresco', 'coriandolo', 'prezzemolo']
# ---------------
# 686
# 2/3 cup dark brown sugar;2/3 cup granulated sugar;1 tablespoon cinnamon;24 ounces refrigerated flaky buttermilk biscuits (tubes);8 ounces cream cheese (package, cut into 20 cubes);3/4 cup butter (melted)
# ['2/3', 'cup', 'dark brown', 'sugar', '2/3', 'cup', 'granulated', 'sugar', '1', 'tablespoon', 'cinnamon', '24', 'ounces', 'refrigerated', 'flaky buttermilk biscuits', 'tubes', '8', 'ounces', 'cream cheese', 'cut into 20 cubes', '3/4', 'cup', 'butter', 'melted']
# 2/3 tazza marrone scuro zucchero;2/3 tazza granulato zucchero;1 cucchiaio cannella;24 once refrigerato biscotti al latticello a scaglie (tubi);8 once crema di formaggio (tagliato in 20 cubetti);3/4 tazza burro (fuso)
# 157 g marrone scuro zucchero;157 g granulato zucchero;1 cucchiaio cannella;680 g refrigerato biscotti al latticello a scaglie (tubi);226 g crema di formaggio (tagliato in 20 cubetti);177 g burro (fuso)
# ['157', 'g', 'marrone scuro', 'zucchero', '157', 'g', 'granulato', 'zucchero', '1', 'cucchiaio', 'cannella', '680', 'g', 'refrigerato', 'biscotti al latticello a scaglie', 'tubi', '226', 'g', 'crema di formaggio', 'tagliato in 20 cubetti', '177', 'g', 'burro', 'fuso']
# ---------------
# 687
# spinach (Wrap, or wrap of your choice);hummus (I used traditional, but any flavor will do);cucumber (diced);red pepper (diced);shredded carrots;tomato (diced);lettuce (shredded)
# ['spinach', 'Wrap', 'hummus', 'cucumber', 'diced', 'red', 'pepper', 'diced', 'shredded', 'carrots', 'tomato', 'diced', 'lettuce', 'shredded']
# spinaci (Avvolgimento, Hummus (cetriolo (a cubetti);rosso pepe (a cubetti);triturati carote;tomato (a cubetti);lattuga (triturati)
# spinaci (Avvolgimento, Hummus (cetriolo (a cubetti);rosso pepe (a cubetti);triturati carote;tomato (a cubetti);lattuga (triturati)
# ['spinaci', 'Avvolgimento', 'Hummus', 'cetriolo', 'a cubetti', 'rosso', 'pepe', 'a cubetti', 'triturati', 'carote', 'tomato', 'a cubetti', 'lattuga', 'triturati']
# ---------------
# 688
# 2 loaves frozen bread dough ({YEP, I cheated});cinnamon;3 sticks butter ({hope you are not worried about your diet});brown sugar;white sugar;vanilla ice cream
# ['2', 'loaves', 'frozen', 'bread dough', 'cinnamon', '3', 'sticks', 'butter', 'brown', 'sugar', 'white', 'sugar', 'vanilla ice cream']
# 2 pani congelato pasta di pane ({cannella;3 bastoncini burro ({marrone zucchero;bianco zucchero;gelato alla vaniglia
# 2 pani congelato pasta di pane ({cannella;3 bastoncini burro ({marrone zucchero;bianco zucchero;gelato alla vaniglia
# ['2', 'pani', 'congelato', 'pasta di pane', 'cannella', '3', 'bastoncini', 'burro', 'marrone', 'zucchero', 'bianco', 'zucchero', 'gelato alla vaniglia']
# ---------------
# 689
# 1 fresh lime;3 drops food colouring (purple);1 tablespoon sugar;1/2 cup vodka (Black vodka is even better);1/3 cup lime juice;1/4 cup raspberry liqueur
# ['1', 'fresh', 'lime', '3', 'drops', 'food colouring', 'purple', '1', 'tablespoon', 'sugar', '1/2', 'cup', 'vodka', 'Black vodka', '1/3', 'cup', 'lime juice', '1/4', 'cup', 'raspberry liqueur']
# 1 fresco lime;3 gocce coloranti alimentari (viola);1 cucchiaio zucchero;1/2 tazza vodka (Vodka nera 1/3 tazza succo di lime;1/4 tazza liquore al lampone
# 1 fresco lime;3 gocce coloranti alimentari (viola);1 cucchiaio zucchero;118 g vodka (Vodka nera 78 g succo di lime;59 g liquore al lampone
# ['1', 'fresco', 'lime', '3', 'gocce', 'coloranti alimentari', 'viola', '1', 'cucchiaio', 'zucchero', '118', 'g', 'vodka', 'Vodka nera', '78', 'g', 'succo di lime', '59', 'g', 'liquore al lampone']
# ---------------
# 690
# blueberries (optional);3 pounds strawberries (optional);2 packages vanilla (JELL-O, pudding3 - 4 cups, 24 - 32 oz.);4 cups cold milk;4 cups whipped cream (Fresh);1 loaf cake;11.5 ounces butter
# ['blueberries', '3', 'pounds', 'strawberries', '2', 'packages', 'vanilla', 'pudding3', '4', 'cups', 'cold', 'milk', '4', 'cups', 'whipped', 'cream', 'Fresh', '1', 'loaf cake', '11.5', 'ounces', 'butter']
# mirtilli (3 chili fragole (2 pacchetti vaniglia (budino3 - 4 tazze freddo latte;4 tazze montata crema (Fresco);1 torta a forma di pagnotta;11.5 once burro
# mirtilli (1,4 kg fragole (2 pacchetti vaniglia (budino708 - 944 g freddo latte;944 g montata crema (Fresco);1 torta a forma di pagnotta;326 g burro
# ['mirtilli', '1,4', 'kg', 'fragole', '2', 'pacchetti', 'vaniglia', 'budino708 -', '4', 'g', 'freddo', 'latte', '944', 'g', 'montata', 'crema', 'Fresco', '1', 'torta a forma di pagnotta', '326', 'g', 'burro']
# ---------------
# 691
# 1 pint softened vanilla ice cream;1 1/2 cups self-raising flour;1 teaspoon vanilla extract (optional);1 teaspoon ground cinnamon;1/2 cup raisins
# ['1', 'pint', 'softened', 'vanilla ice cream', '1 1/2', 'cups', 'self-raising flour', '1', 'teaspoon', 'vanilla extract', '1', 'teaspoon', 'ground', 'cinnamon', '1/2', 'cup', 'raisins']
# 1 pinta ammorbidito gelato alla vaniglia;1 1/2 tazze farina autolievitante;1 cucchiaino estratto di vaniglia (1 cucchiaino macinato cannella;1/2 tazza uvetta
# 473 ml ammorbidito gelato alla vaniglia;354 g farina autolievitante;1 cucchiaino estratto di vaniglia (1 cucchiaino macinato cannella;118 g uvetta
# ['473', 'ml', 'ammorbidito', 'gelato alla vaniglia', '354', 'g', 'farina autolievitante', '1', 'cucchiaino', 'estratto di vaniglia', '1', 'cucchiaino', 'macinato', 'cannella', '118', 'g', 'uvetta']
# ---------------
# 692
# 1 scoop vanilla ice cream;2 cookies (any kind of cookies)
# ['1', 'scoop', 'vanilla ice cream', '2', 'cookies']
# 1 ambito di applicazione gelato alla vaniglia;2 biscotti (
# 1 ambito di applicazione gelato alla vaniglia;2 biscotti (
# ['1', 'ambito di applicazione', 'gelato alla vaniglia', '2', 'biscotti']
# ---------------
# 693
# 12 ounces cola soft drink;10 ounces teriyaki sauce;1 london broil (2 1/2- to 3-pound)
# ['12', 'ounces', 'cola soft drink', '10', 'ounces', 'teriyaki sauce', '1', 'london broil', '2 1/2- to 3', 'pound']
# 12 once bevanda analcolica alla cola;10 once salsa teriyaki;1 london broil (Da 2 1/2 a 3-sterlina)
# 340 g bevanda analcolica alla cola;283 g salsa teriyaki;1 london broil (Da 2 1/2 a 3-sterlina)
# ['340', 'g', 'bevanda analcolica alla cola', '283', 'g', 'salsa teriyaki', '1', 'london broil', 'Da 2 1/2 a 3', 'sterlina']
# ---------------
# 694
# 2.5 ounces gin ( , or vodka);0.5 ounces dry vermouth ( );0.5 ounces olive brine ( )
# ['2.5', 'ounces', 'gin', 'vodka', '0.5', 'ounces', 'dry', 'vermouth', '0.5', 'ounces', 'olive brine']
# 2.5 once gin ( , vodka);0.5 once asciutto vermouth ( );0.5 once salamoia di olive ( )
# 70 g gin ( , vodka);14 g asciutto vermouth ( );14 g salamoia di olive ( )
# ['70', 'g', 'gin', 'vodka', '14', 'g', 'asciutto', 'vermouth', '14', 'g', 'salamoia di olive']
# ---------------
# 695
# 9 eggs;1 (10 ounce) bag Baby Spinach;1 medium onion, chopped;1 tablespoon oil;1 cup cheddar cheese;salt;pepper
# ['9', 'eggs', '1', '10', 'ounce', 'bag', 'Baby Spinach', '1', 'medium', 'onion', 'chopped', '1', 'tablespoon', 'oil', '1', 'cup', 'cheddar cheese', 'salt', 'pepper']
# 9 uova;1 (10 oncia) borsa Spinaci baby;1 medio cipolla, tritato;1 cucchiaio olio;1 tazza formaggio cheddar;sale;pepe
# 9 uova;1 (283 g) borsa Spinaci baby;1 medio cipolla, tritato;1 cucchiaio olio;236 g formaggio cheddar;sale;pepe
# ['9', 'uova', '1', '283', 'g', 'borsa', 'Spinaci baby', '1', 'medio', 'cipolla', 'tritato', '1', 'cucchiaio', 'olio', '236', 'g', 'formaggio cheddar', 'sale', 'pepe']
# ---------------
# 696
# 1 cup coffee (freshly-brewed hot);1.5 ounces Irish whiskey;3 teaspoons turbinado sugar (or brown sugar);whipped cream;ground nutmeg (Optional toppings: freshly-, or chocolate shavings)
# ['1', 'cup', 'coffee', 'freshly-brewed hot', '1.5', 'ounces', 'Irish whiskey', '3', 'teaspoons', 'turbinado sugar', 'brown', 'sugar', 'whipped', 'cream', 'ground', 'nutmeg', 'chocolate shavings']
# 1 tazza caffè (caldo appena fatto);1.5 once Whisky irlandese;3 cucchiaini zucchero turbinado (marrone zucchero);montata crema;macinato noce moscata (scaglie di cioccolato)
# 236 g caffè (caldo appena fatto);42 g Whisky irlandese;3 cucchiaini zucchero turbinado (marrone zucchero);montata crema;macinato noce moscata (scaglie di cioccolato)
# ['236', 'g', 'caffè', 'caldo appena fatto', '42', 'g', 'Whisky irlandese', '3', 'cucchiaini', 'zucchero turbinado', 'marrone', 'zucchero', 'montata', 'crema', 'macinato', 'noce moscata', 'scaglie di cioccolato']
# ---------------
# 697
# 5 pounds ground beef (the leaner the better);4 onions (minced, whatever type you prefer);20 garlic cloves (minced);1/2 cup beef broth
# ['5', 'pounds', 'ground', 'beef', '4', 'onions', 'minced', '20', 'garlic', 'cloves', 'minced', '1/2', 'cup', 'beef broth']
# 5 chili macinato manzo (4 cipolle (tritato, 20 aglio chiodi di garofano (tritato);1/2 tazza brodo di manzo
# 2,2 kg macinato manzo (4 cipolle (tritato, 20 aglio chiodi di garofano (tritato);118 g brodo di manzo
# ['2,2', 'kg', 'macinato', 'manzo', '4', 'cipolle', 'tritato', '20', 'aglio', 'chiodi di garofano', 'tritato', '118', 'g', 'brodo di manzo']
# ---------------
# 698
# 1 1/2 ounces tequila;2 ounces pineapple juice;1 ounce lemon juice (fresh, if possible);1/2 ounce grenadine
# ['1 1/2', 'ounces', 'tequila', '2', 'ounces', 'pineapple juice', '1', 'ounce', 'lemon juice', 'fresh, if possible', '1/2', 'ounce', 'grenadine']
# 1 1/2 once tequila;2 once succo d'ananas;1 oncia succo di limone (freschi, se possibile);1/2 oncia granatina
# 42 g tequila;56 g succo d'ananas;28 g succo di limone (freschi, se possibile);14 g granatina
# ['42', 'g', 'tequila', '56', 'g', "succo d'ananas", '28', 'g', 'succo di limone', 'freschi, se possibile', '14', 'g', 'granatina']
# ---------------
# 699
# 14 ounces artichoke hearts (drained and chopped);10 ounces frozen spinach (chopped, thawed and drained);1 cup mayonnaise;1 cup grated Parmesan cheese;2 1/2 cups shredded Monterey Jack cheese
# ['14', 'ounces', 'artichoke', 'hearts', 'drained', 'chopped', '10', 'ounces', 'frozen', 'spinach', 'chopped', 'thawed', 'drained', '1', 'cup', 'mayonnaise', '1', 'cup', 'grated', 'Parmesan cheese', '2 1/2', 'cups', 'shredded', 'Monterey Jack cheese']
# 14 once carciofo cuori (scolato tritato);10 once congelato spinaci (tritato, scongelato scolato);1 tazza maionese;1 tazza grattugiato Parmigiano Reggiano;2 1/2 tazze triturati Formaggio Monterey Jack
# 396 g carciofo cuori (scolato tritato);283 g congelato spinaci (tritato, scongelato scolato);236 g maionese;236 g grattugiato Parmigiano Reggiano;590 g triturati Formaggio Monterey Jack
# ['396', 'g', 'carciofo', 'cuori', 'scolato', 'tritato', '283', 'g', 'congelato', 'spinaci', 'tritato', 'scongelato', 'scolato', '236', 'g', 'maionese', '236', 'g', 'grattugiato', 'Parmigiano Reggiano', '590', 'g', 'triturati', 'Formaggio Monterey Jack']
# ---------------
